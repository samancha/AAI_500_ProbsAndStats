# %% [markdown]
# # Assignment 1.1

# %% [markdown]
# Name:  Steve Amancha
# Date:  May 9th 2023

# %% [markdown]
# For this assignment, you will refer to the textbook to solve the practice exercises. **Use Python to answer any coding problems (not R, even if indicated in your textbook).** Use Jupyter Notebook, Google Colab, or a similar software program to complete your assignment. Submit the assignment as a PDF file. Always label your axes and provide titles for any graphs generated on this assignment. Round all quantitative answers to 2 decimal places.

# %% [markdown]
# ## **Problem # 1.1.**
# In the 2018 election for Senate in California, a CNN exit poll of 1882 voters stated that 52.5% voted for the Democratic candidate, Diane Feinstein. Of all 11.1 million voters, 54.2% voted for Feinstein.
#
# (a) What was the (i) subject, (ii) sample, (iii) population?

# %% [markdown]
# `(a)`
#
# Subject : 2018 Election for Senate in California
# Sample : CNN exit poll of 1882 voters
# Population: 11.1 million voters

# %%
print("Subject : 2018 Election for Senate in California")

print("Sample : CNN exit poll of 1882 voters") 

print("Population: 11.1 million voters")
# Out:
# Subject : 2018 Election for Senate in California
# Sample : CNN exit poll of 1882 voters
# Population: 11.1 million voters

# %% [markdown]
# ## **Problem # 1.2.**
# The `Students` data file at [http://stat4ds.rwth-aachen.de/data/Students.dat](http://stat4ds.rwth-aachen.de/data/Students.dat) responses of a class of 60
# social science graduate students at the University of Florida to a questionnaire that asked about *gender* (1 = female, 0 = male), *age*, *hsgpa* = high school GPA (on a four-point scale), cogpa = college GPA, *dhome* = distance (in miles) of the campus from your home town, *dres* = distance (in miles) of the classroom from your current residence, *tv* = average number of hours per week that you watch TV, *sport* = average number of hours per week that you participate in sports or have other physical exercise, *news* = number of
# times a week you read a newspaper, *aids* = number of people you know who have died from AIDS or who
# are HIV+, *veg* = whether you are a vegetarian (1 = yes, 0 = no), *affil* = political affiliation (1 = Democrat, 2
# = Republican, 3 = independent), *ideol* = political ideology (1 = very liberal, 2 = liberal, 3 = slightly liberal, 4
# = moderate, 5 = slightly conservative, 6 = conservative, 7 = very conservative), *relig* = how often you
# attend religious services (0 = never, 1 = occasionally, 2 = most weeks, 3 = every week), *abor* = opinion
# about whether abortion should be legal in the first three months of pregnancy (1 = yes, 0 = no), *affirm* =
# support affirmative action (1 = yes, 0 = no), and *life* = belief in life after death (1 = yes, 2 = no, 3 =
# undecided). You will use this data file for some exercises in this book.

# %% [markdown]
# (a) Practice accessing a data file for statistical analysis with your software by going to the book’s
#      website and copying and then displaying this data file.

# %% [markdown]
# `(a) Your answer goes here`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
from sklearn.linear_model import LinearRegression

# %%
data_url = 'https://stat4ds.rwth-aachen.de/data/Students.dat'
students = pd.read_csv(data_url, delim_whitespace=True)
dataframe = pd.DataFrame(students)
display(dataframe)
# Out:
#     subject  gender  age  hsgpa  cogpa  dhome   dres    tv  sport  news  aids
# 0         1       0   32    2.2    3.5      0   5.00   3.0      5     0     0  \
# 1         2       1   23    2.1    3.5   1200   0.30  15.0      7     5     6
# 2         3       1   27    3.3    3.0   1300   1.50   0.0      4     3     0
# 3         4       1   35    3.5    3.2   1500   8.00   5.0      5     6     3
# 4         5       0   23    3.1    3.5   1600  10.00   6.0      6     3     0
# 5         6       0   39    3.5    3.5    350   3.00   4.0      5     7     0
# 6         7       0   24    3.6    3.7      0   0.20   5.0     12     4     2
# 7         8       1   31    3.0    3.0   5000   1.50   5.0      3     3     1
# 8         9       0   34    3.0    3.0   5000   2.00   7.0      5     3     0
# 9        10       0   28    4.0    3.1    900   2.00   1.0      1     2     1
# 10       11       0   23    2.3    2.6    253   1.50  10.0     15     1     1
# ...

# %% [markdown]
# (b) Using responses on *abor*, state a question that could be addressed with (i) descriptive
#      statistics, (ii) inferential statistics.

# %% [markdown]
# (i) What percentage of students believe abortion should be legal in the first three months of pregnancy?
#
#
#
# (ii) Do a majority of the students believe abortion should be legal in the first three months of pregnancy?

# %% [markdown]
# ## **Problem # 1.3.**
# Identify each of the following variables as categorical or quantitative: (a) Number of smartphones that you own; (b) County of residence; (c) Choice of diet (vegetarian, nonvegetarian); (d) Distance, in kilometers, commute to work

# %% [markdown]
# (a) Number of smartphones that you own : quantitative
#
# (b) County of residence : categorical
#
# (c) Choice of diet (vegetarian, nonvegetarian) : categorical
#
# (d) Distance, in kilometers, commute to work : quantitative

# %% [markdown]
# ## **Problem # 1.4.**
# Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous

# %% [markdown]
# (a) categorical : Music Genres
#
# (b) quantitative : Weight of a dog
#
# (c) discrete : Number of pets owned
#
# (d) continuous : Temperature

# %% [markdown]
# ## **Problem # 1.10.**
# Analyze the `Carbon_West` ([http://stat4ds.rwth-aachen.de/data/Carbon_West.dat](http://stat4ds.rwth-aachen.de/data/Carbon_West.dat)) data file at the book’s website by **(a)** constructing a frequency distribution and  a histogram, **(b)** finding the mean, median, and standard deviation. Interpret each.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import math
import scipy.stats
from sklearn.linear_model import LinearRegression
import seaborn as sns

# Reading data and displaying raw data fram
data_url = 'https://stat4ds.rwth-aachen.de/data/Carbon_West.dat'
cw_data = pd.read_csv(data_url, delim_whitespace=True)
dataframe = pd.DataFrame(cw_data)

#display freq (is a type Series)
freq = dataframe['CO2'].value_counts()
print("Dispalying fequence table")
display(freq.to_frame())

# Creating the plot 
print("Dispalying fequence Histogram of CO2 dataset")
sns.histplot(data=freq.index.values, bins='auto')

# Adding labels, titles, and showing my plot
plt.xlabel("CO2 Levels (Per capita)")
plt.ylabel("Frequency")
plt.title("Fequence Histogram of World C02 Levels")
plt.show()


print("PART 2:")

display(dataframe['CO2'].values)

median = round(np.median(dataframe['CO2'].values),2)
mean = round(np.mean(dataframe['CO2'].values),2)
std = round(np.std(dataframe['CO2'].values),2)
print("Median: ", median)
print("Mean: ", mean )
print("Standard Deviation:", std)
# Out:
# Dispalying fequence table
#       count
# CO2
# 4.3       3
# 6.2       3
# 5.3       3
# 3.5       2
# 5.9       2
# 6.5       1
# 4.5       1
# 5.0       1
# 5.7       1
# 9.3       1
# 7.7       1
# 9.9       1
# 3.6       1
# 5.4       1
# 4.4       1
# 2.0       1
# 7.3       1
# 15.4      1
# 8.9       1
# 4.6       1
# 8.7       1
# 9.2       1
# 4.0       1
# 15.1      1
# 8.3       1
# 6.9       1
# 16.5      1
# Dispalying fequence Histogram of CO2 dataset
# PART 2:
# array([ 2. , 15.4,  6.9,  8.3,  6.2,  5.9, 15.1,  4. ,  5.3,  9.2,  5.9,
#         8.7,  4.6,  8.9,  6.2,  4.3,  7.3,  5.3,  3.5,  4.4,  5.4,  3.6,
#         9.9,  7.7,  9.3,  4.3,  3.5,  5.3,  5.7,  6.2,  5. ,  4.5,  4.3,
#         6.5, 16.5])
# Median:  5.9
# Mean:  6.72
# Standard Deviation: 3.31

# %% [markdown]
# Median:  5.9
# Mean:  6.72
# Standard Deviation: 3.31
#
# Median Interpretation: I believe this is the more accurate value representation because it's a right skwed distribution, and the median is resistant to outliers like in the 14 to 16 range.
#
# Mean Interpretation: The mean is the average of the dataset and the graph confirms that the average falls in the most popular range.
#
# Standard Interpretation: This is normally the range or distance of an observation from the mean. The range the STD makes with the mean (3.41 - 10.03) from the mean covers a majority of the countiries.

# %% [markdown]
# ## **Problem # 1.11.**
# According to Statistics Canada, for the Canadian population having income in 2019, annual income had a median of `$`35,000 and mean of `$`46,700. What would you predict about the shape of the distribution? Why?

# %% [markdown]
# Since the mean 46,700 is greater than the median 35,000, we can predict that the income distribution for the Canadian population in 2019 is likely positively skewed or right-skewed. This means that the majority of the population may have lower incomes, with a few higher-income individuals or outliers that significantly impact the mean.

# %% [markdown]
# ## **Problem # 1.13.**
# A report indicates that public school teacher’s annual salaries in New York city have an approximate  mean of `$`69,000 and standard deviation of `$`6,000. If the distribution has approximately a bell shape, report intervals that contain about (a) 68%, (b) 95%, (c) all or nearly all salaries. Would a salary of  `$`100,000 be unusual? Why?

# %% [markdown]
# a) +/- 1 std of 6000 away from 69000 creates a range of 63000 - $75000
#
# b) +/- 2 std of 6000 away from 69000 creates a range of 57000 - $81000
#
# c) +/- 3 std of 6000 away from 69000 creates a range of 51000 - $87000
#
#
# With a salary of $100,000. To determine if it is unusual, we need to check how many standard deviations it is away from the mean.
#
# Calculate the z-score using the formula:
#
# z = (x - mean) / standard deviation
#
# z = (100,000 - 69,000) / 6,000 = 31 / 6 ≈ 5.17
#
# A z-score of 5.17 indicates that a salary of 100,000 is approximately 5.17 standard deviations above the mean. Therefore, a salary of $100,000 would be considered unusual in this context.

# %% [markdown]
# ## **Problem # 1.17.**
# From the `Murder` data file ([http://stat4ds.rwth-aachen.de/data/Murder.dat](http://stat4ds.rwth-aachen.de/data/Murder.dat)) at the book’s website, use the variable murder, which is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC). Using software:
# (a) Find the mean and standard deviation and interpret their values.
# (b) Find the five-number summary, and construct the corresponding box plot. Interpret.
# (c) Now include the observation for D.C. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a)`

# %%
# reading a creating df from murder data with columns state and murder
data_url = 'https://stat4ds.rwth-aachen.de/data/Murder.dat'
cw_data = pd.read_csv(data_url, delim_whitespace=True)
df = pd.DataFrame(cw_data)

mean = np.mean(df['murder'])
std = np.std(df['murder'])
print("Murders per 100,000 people")
print('Mean: ', round(mean,2), 'people')
print('Std: ', round(std,2), 'people')
# Out:
# Murders per 100,000 people
# Mean:  5.25 people
# Std:  3.69 people

# %% [markdown]
# Interpretation:
#
# Mean: On average 5 people are murder per 100,000 in the country.
#
# STD: +/- the STD combined with the mean creates a range of ~1.5 - 9 murders for a majority of the country.

# %% [markdown]
# `(b)`
#
# Interpretation:
# The five number summary showed tells me that a at least every state has at least 1 murder and a maximum of 24.2 murders.
# It also displayed a more left leaning skew which means that a majority of the states had less than 5 murders.

# %%
# Creating five points summary of data set
five_num_summary = df.describe().loc[['min', '25%', '50%', '75%', 'max']]
print(five_num_summary)
sns.boxplot(data=df, x=df['murder'], color='lightgreen')
plt.xlabel('Murder rate')
plt.ylabel('All states')
plt.title('Box Plot for US Murder Rates')
plt.show()
# Out:
#      murder
# min    1.00
# 25%    2.65
# 50%    5.00
# 75%    6.45
# max   24.20

# %% [markdown]
# `(c)`
#
# For D.C, the mean is impacted more because it adds a larger number to the total sum or murders. Also the median is resistant to outliers.
#
# The range is impacted more than the inter quartile range because the IQR is not affected by outliers and takes into account variability by observations other than the most extreme ones

# %% [markdown]
# ## **Problem # 1.18.**
# The `Income` data file ([http://stat4ds.rwth-aachen.de/data/Income.dat](http://stat4ds.rwth-aachen.de/data/Income.dat)) at the book’s website reports annual income values in the U.S., in thousands of dollars.
#
# (a) Using software, construct a histogram. Describe its shape.
# (b) Find descriptive statistics to summarize the data. Interpret them.
# (c) The kernel density estimation method finds a smooth-curve approximation for a histogram. At each value, it takes into account how many observations are nearby and their distance, with more weight given those closer. Increasing the bandwidth increases the influence of observations further away. Plot a smooth-curve approximation for the histogram of income values. Summarize the impact of increasing and of decreasing the bandwidth substantially from the default value.
# (d) Construct and interpret side-by-side box plots of income by race (B = Black, H = Hispanic, W = White).  Compare the incomes using numerical descriptive statistics

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a)`
#
# Describing the form of the histogram:
#
# The historgram of education seems like bell curved with a slight skew to the right based off the uneven bell curve. Most of the values fall in side the curve of the KDE.
#
# The histogram of the income seems like a heavily skewed to the right curve because of the outliers at 120 and 104. If they weren't there I would assume a more evenly distributed bell curve.

# %%
# Reading data and create df with columns income, education, race
income_df = pd.read_csv('Income.dat', delim_whitespace=True)

# Creating the plot 
# Using this approach to handle multi variable histogram
col_var = ['income', 'education','race']
sns.histplot(data=income_df[col_var], bins='auto', kde=True)

# Adding labels, titles, and showing my plot
plt.xlabel("Dollars per hundred thousand (Blue) and Age (Years)")
plt.ylabel("Frequency")
plt.title("Histogram of Income and Education")
plt.show()

# %% [markdown]
# `(b)`
#
# Summarize:
#
# Looking at the five number summary data I'm able to see.
#
# income:
# The 50th percentile makes 30000 dollars annually and the range to the upper 75th percentile is more than the range to the lower 25th percentile, which means the distrubtion leans more heavily to the right side / right skewed.
#
# education:
# Looking at the std from the 50th percentile, I noticed that the difference from the mean to the 25th percentile and the 75th percentile is only off by one. Since this is almost equal, the plot is almost evenly distrubted like a bell curve. The min and max are the range of the data / plot.

# %%
five_num_summary = income_df.describe().loc[['min', '25%', '50%', '75%', 'max']]
print(five_num_summary)
# Out:
#      income  education
# min    16.0        7.0
# 25%    22.0       10.0
# 50%    30.0       12.0
# 75%    46.5       15.0
# max   120.0       20.0

# %% [markdown]
# `(c)`
#
# Increasing the bandwidth will result in a smoother curve, spreading the influence of observations further away. This can lead to a loss of detail and potentially oversmoothing the distribution, making it less sensitive to local variations in the data.
# Decreasing the bandwidth will result in a more jagged or wiggly curve, capturing more local variations in the distribution. However, excessively decreasing the bandwidth can lead to noise and make the curve overly sensitive to small fluctuations in the data.
# By adjusting the bandwidth, you can control the trade-off between capturing fine-grained details and obtaining a smoother representation of the underlying distribution. It's important to experiment with different bandwidth values to strike the right balance based on the characteristics and features of your data.

# %%
#sns.histplot(data=income_df['income'], bins='auto', kde=True)
sns.kdeplot(data=income_df['income'])

plt.xlabel("Income (Dollars per hundred thousand)")
plt.ylabel("Density")
plt.title("smooth-curve approximation Histogram of Income with KDE")
plt.show()

# %% [markdown]
# `(d) Your answer goes here`
# Construct and interpret side-by-side box plots of income by race (B = Black, H = Hispanic, W = White). Compare the incomes using numerical descriptive statistics
#
# Overall, the 50 percentile makes 30k. This seems to be around the mean for hispanics, where the white people makes closer to 40k, and black people 25k. The outliers and max are higher for white people, then black, and then hispanic.

# %%
five_num_summary = income_df.describe().loc[['min', '25%', '50%', '75%', 'max']]
print(five_num_summary)

# creating and labeling plot
sns.boxplot(data=income_df, x='race', y='income', color='red')
plt.xlabel('Race (B = black, H = hispanic, W = white)')
plt.ylabel('Income (K)')
plt.title('Income by Race')
plt.show()
# Out:
#      income  education
# min    16.0        7.0
# 25%    22.0       10.0
# 50%    30.0       12.0
# 75%    46.5       15.0
# max   120.0       20.0

# %% [markdown]
# ## **Problem # 1.19.**
# The `Houses` data file ([http://stat4ds.rwth-aachen.de/data/Houses.dat](http://stat4ds.rwth-aachen.de/data/Houses.dat)) at the book’s website lists the selling price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let’s analyze the selling prices.
#
# (a) Construct a frequency distribution and a histogram. Describe the shape.
# (b) Find the percentage of observations that fall within one standard deviation of the mean. Why is this not close to 68%?
# (c) Construct a box plot, and interpret.
# (d) Use descriptive statistics to compare selling prices according to whether the house is new.

# %% [markdown]
# **Answer:**

# %% [markdown]
# `(a)`
#
# The shape is a high skwed right plot with a few highly priced houses as outliers and the highly priced houses also are less in frequency.

# %%
data_url = 'https://stat4ds.rwth-aachen.de/data/Houses.dat'
house_data = pd.read_csv(data_url, delim_whitespace=True)

# Reading data and displaying raw data fram
df = pd.DataFrame(house_data)
display(df)

# display freq (is a type Series)
freq = df['price'].value_counts()
display(freq.to_frame())

# # Creating the plot 
sns.histplot(data=freq.index.values, bins='auto')

# Adding labels, titles, and showing my plot
plt.xlabel("House price (Thousands of dollars)")
plt.ylabel("Frequency")
plt.title("Fequence Histogram of Housing Price Dataset")
plt.show()
# Out:
#     case   price  size  new  taxes  bedrooms  baths
# 0      1  419.85  2048    0   3104         4      2
# 1      2  219.75   912    0   1173         2      1
# 2      3  356.55  1654    0   3076         4      2
# 3      4  300.00  2068    0   1608         3      2
# 4      5  239.85  1477    0   1454         3      3
# ..   ...     ...   ...  ...    ...       ...    ...
# 95    96  264.00  1060    0    990         2      2
# 96    97  294.75  1730    0   3030         3      2
# 97    98  198.30  1370    0   1580         3      2
# 98    99  132.60  1560    0   1770         3      2
# 99   100  190.80  1340    0   1430         3      2
#
# [100 rows x 7 columns]
#         count
# price
# 150.00      3
# 205.50      3
# 127.50      3
# 210.00      3
# 104.85      2
# ...       ...
# 90.00       1
# 190.50      1
# 129.00      1
# 75.00       1
# 190.80      1
#
# [81 rows x 1 columns]

# %% [markdown]
# `(b)`
#
# The value of 68% corresponds to the percentage of observations within one standard deviation for a normally distributed dataset. Since the housing price data has a few major outliers, the percentage within one standard deviation deviates from 68%.

# %%
mean_income = df['price'].mean()
std_income = df['price'].std()
lower_bound = mean_income - std_income
upper_bound = mean_income + std_income

# Recreates array to only include values within the range and I find the percentage 
within_one_std = df[(df['price'] >= lower_bound) & (df['price'] <= upper_bound)]
percentage_within_one_std = (len(within_one_std) / len(df)) * 100

print(f"Mean : {mean_income:.2f}")
print(f"Range : {lower_bound:.2f}-{upper_bound:.2f}")
print(f"Percentage within one standard deviation: {percentage_within_one_std:.2f}%")
print(f"Standard Deviation: {std_income:.2f}")
# Out:
# Mean : 233.00
# Range : 81.10-384.89
# Percentage within one standard deviation: 85.00%
# Standard Deviation: 151.89

# %% [markdown]
# `(c)`
#  Construct a box plot, and interpret.
#
# I can see that there are a lot of expensive houses because of the amount of higher end outliers.

# %%
# Creating a box plot with housing prices
sns.boxplot(data=df, x='price', color='red')
plt.xlabel('Housing Price (thousands of dollars)')
plt.ylabel('Houses')
plt.title('Box Plot of Housing Prices')
plt.show()

# %% [markdown]
# `(d)` The mean is alot more expensive for selling new houses and there are a lot more non-new houses for sale.

# %%
# Seperate data set into array of new and non new houses
new_houses = df[df['new'] == 1]
non_new_houses = df[df['new'] == 0]

# Created stats 
new_houses_stats = round(new_houses['price'].describe(),2)
non_new_houses_stats = round(non_new_houses['price'].describe(),2)

print("Descriptive Statistics - Selling Prices for New Houses:")
print(new_houses_stats)
print("\nDescriptive Statistics - Selling Prices for Non-New Houses:")
print(non_new_houses_stats)
# Out:
# Descriptive Statistics - Selling Prices for New Houses:
# count     11.00
# mean     436.45
# std      219.83
# min      158.85
# 25%      256.95
# 50%      427.50
# 75%      519.67
# max      866.25
# Name: price, dtype: float64
#
# Descriptive Statistics - Selling Prices for Non-New Houses:
# count     89.00
# mean     207.85
# std      121.04
# min       31.50
# 25%      135.00
# 50%      190.80
# 75%      240.00
# max      880.50
# Name: price, dtype: float64
